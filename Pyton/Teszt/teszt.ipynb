# %% [markdown]
# Valamit írok ide

# %%
print ("Valami")
# Out:
# Valami

# %%
print (" Két valami")
print (" Két valami")
# Out:
#  Két valami
#  Két valami

# %%
valtozo = "11"

valtozo = int(valtozo)

print(valtozo)
print(type (valtozo))
# Out:
# 11
# <class 'int'>

# %%
print(__name__)
# Out:
# __main__
